# %% [markdown]
# <a href="https://colab.research.google.com/github/Iswarya-c123/dhina-travels/blob/main/dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Dataset (10 values)
marks = np.array([85, 90, 78, 92, 88, 75, 95, 80, 86, 91])

print("Dataset:", marks)
print("Mean:", np.mean(marks))
print("Maximum:", np.max(marks))
print("Minimum:", np.min(marks))
print("Sum:", np.sum(marks))
print("Standard Deviation:", np.std(marks))
print("Median:", np.median(marks))
# Out:
# Dataset: [85 90 78 92 88 75 95 80 86 91]
# Mean: 86.0
# Maximum: 95
# Minimum: 75
# Sum: 860
# Standard Deviation: 6.196773353931867
# Median: 87.0
